# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
import pandas as pd
from sklearn.metrics import r2_score
from sklearn import datasets

# %%
df = datasets.load_diabetes(as_frame=True).frame

# %%
df.head()
df.shape
# Out:
# (442, 11)

# %%
X = df.drop("target", axis=1)
y = df["target"]

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
X_train.head()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 225  0.030811  0.050680  0.032595  0.049415 -0.040096 -0.043589 -0.069172
# 412  0.074401 -0.044642  0.085408  0.063187  0.014942  0.013091  0.015505
# 118 -0.056370  0.050680 -0.010517  0.025315  0.023198  0.040022 -0.039719
# 114  0.023546 -0.044642  0.110198  0.063187  0.013567 -0.032942 -0.024993
# 364  0.001751  0.050680 -0.006206 -0.019442 -0.009825  0.004949 -0.039719
#
#            s4        s5        s6
# 225  0.034309  0.063015  0.003064
# 412 -0.002592  0.006207  0.085907
# 118  0.034309  0.020609  0.056912
# 114  0.020655  0.099241  0.023775
# 364  0.034309  0.014821  0.098333

# %%
scaler = StandardScaler()

y_train_scaled = scaler.fit_transform(y_train.values.reshape(-1, 1)).ravel()
y_test_scaled = scaler.transform(y_test.values.reshape(-1, 1)).ravel()

# %%
model = SVR()

model.fit(X_train, y_train_scaled)
# Out:
# SVR()

# %%
y_pred_test_scaled = model.predict(X_test)
y_pred_train_scaled = model.predict(X_train)

print("test r2 score: ", r2_score(y_test_scaled, y_pred_test_scaled))
print("train r2 score: ",  r2_score(y_train_scaled, y_pred_train_scaled))
# Out:
# test r2 score:  0.48844443151651884
# train r2 score:  0.6596361676267712

# %%
models = ["linear", "poly", "rbf", "sigmoid"]

for i in models:
    model = SVR(kernel=i)
    model.fit(X_train, y_train_scaled)
    
    y_pred_test_scaled = model.predict(X_test)
    y_pred_train_scaled = model.predict(X_train)
    
    print("test r2 score: ", r2_score(y_test_scaled, y_pred_test_scaled), "for kernel = ", i)
    print("train r2 score: ",  r2_score(y_train_scaled, y_pred_train_scaled), "for kernel =", i, "\n")
# Out:
# test r2 score:  0.4433761323833776 for kernel =  linear
# train r2 score:  0.45191229982475245 for kernel = linear
#
# test r2 score:  0.24203771038107758 for kernel =  poly
# train r2 score:  0.5790920834310542 for kernel = poly
#
# test r2 score:  0.48844443151651884 for kernel =  rbf
# train r2 score:  0.6596361676267712 for kernel = rbf
#
# test r2 score:  -15.316808189576822 for kernel =  sigmoid
# train r2 score:  -19.72119344073131 for kernel = sigmoid

# %%
# hyperparameter using GridSearchCV

pram_gird = {"kernel": ("rbf", "poly", "linear"),
            "C":[1, 10, 50, 100],
             "epsilon": [0.01, 0.1, 0.2, 0.3, 0.5]
}

svr = SVR()

grid_search = GridSearchCV(
    svr, pram_gird, scoring="r2", cv=5
)

grid_search.fit(X_train, y_train_scaled)
# Out:
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid={'C': [1, 10, 50, 100],
#                          'epsilon': [0.01, 0.1, 0.2, 0.3, 0.5],
#                          'kernel': ('rbf', 'poly', 'linear')},
#              scoring='r2')

# %%
print("best params = ", grid_search.best_params_)
# Out:
# best params =  {'C': 10, 'epsilon': 0.1, 'kernel': 'linear'}

# %%
best_model = SVR(kernel="linear", C=10, epsilon=0.1)

best_model.fit(X_train, y_train_scaled)
    
y_pred_test_scaled = best_model.predict(X_test)
y_pred_train_scaled = best_model.predict(X_train)

print("test r2 score: ", r2_score(y_test_scaled, y_pred_test_scaled))
print("train r2 score: ",  r2_score(y_train_scaled, y_pred_train_scaled))
# Out:
# test r2 score:  0.47444183250401095
# train r2 score:  0.5151066486918876

# %%
from sklearn.svm import LinearSVR

model = LinearSVR(C=10, epsilon=0.1, max_iter=10000)

model.fit(X_train, y_train_scaled)
    
y_pred_test_scaled = model.predict(X_test)
y_pred_train_scaled = model.predict(X_train)

print("test r2 score: ", r2_score(y_test_scaled, y_pred_test_scaled))
print("train r2 score: ",  r2_score(y_train_scaled, y_pred_train_scaled))
# Out:
# test r2 score:  0.47395416897270637
# train r2 score:  0.5151534626805794
